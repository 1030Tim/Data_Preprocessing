# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = [i for i in range(7)]
y = [0,11,22,33,44,55,66]

plt.scatter(x,y)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
x =[0.3,0.6]
plt.pie(x)
plt.show()
